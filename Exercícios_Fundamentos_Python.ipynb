# %% [markdown]
# <a href="https://colab.research.google.com/github/ericson-j-santos/PYTHON_IMPRESSIONADOR/blob/18.-Exerc%C3%ADcios-e-O-que-falta-aprender-agora/Exerc%C3%ADcios_Fundamentos_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1- Imposto a pagar no Lucro Presumido
#
# - 5% sobre faturamento de ISS (mensal)
# - 0,65% de PIS sobre faturamento, (mensal)
# - 3% de COFINS sobre faturmaneto, (mensal)
# - 4.8% de IR (trimestral)
# - 10% de IR Adicional sobre o que ultrapassar 20mil do faturamento (trimestral)
# - CSLL: 2,88% sobre faturamento (trimestral)

# %%
faturamento = {
    'jan': 'R$ 95.141,98',
    'fev': 'R$ 95.425,16',
    'mar': 'R$ 89.716,31',
    'abr': 'R$ 78.459,99',
    'mai': 'R$ 71.087,28',
    'jun': 'R$ 83.911,06',
    'jul': 'R$ 56.467,26',
    'ago': 'R$ 88.513,58',
    'set': 'R$ 66.552,49',
    'out': 'R$ 80.164,07',
    'nov': 'R$ 66.964,33',
    'dez': 'R$ 71.525,25',
}

# você precisa inserir no sistema um dicionário no formato:

# resultado = {
#     'mes': (faturamento, imposto_mensal, imposto_trimestral),
# }

# %% [markdown]
# ### 2 - Puxando informações de um banco de Dados

# %%
# puxando informações SQL de um banco de dados
informacoes = [(1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0.0, 400184.25, None, 567595.43, 567595.43, 2011, '', 'San Francisco', ''), (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, None, 538909.28, 538909.28, 2011, '', 'San Francisco', ''), (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, None, 335279.91, 335279.91, 2011, '', 'San Francisco', ''), (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 56120.71, 198306.9, None, 332343.61, 332343.61, 2011, '', 'San Francisco', ''), (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737.0, 182234.59, None, 326373.19, 326373.19, 2011, '', 'San Francisco', ''), (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 8601.0, 189082.74, None, 316285.74, 316285.74, 2011, '', 'San Francisco', ''), (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, None, 315981.05, 315981.05, 2011, '', 'San Francisco', ''), (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0.0, 51322.5, None, 307899.46, 307899.46, 2011, '', 'San Francisco', ''), (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, None, 303427.55, 303427.55, 2011, '', 'San Francisco', ''), (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 0.0, 17115.73, None, 302377.73, 302377.73, 2011, '', 'San Francisco', '')]
descricao = (('Id', "<class 'int'>", None, 10, 10, 0, True), ('EmployeeName', "<class 'str'>", None, 65536, 65536, 0, True), ('JobTitle', "<class 'str'>", None, 65536, 65536, 0, True), ('BasePay', "<class 'float'>", None, 54, 54, 0, True), ('OvertimePay', "<class 'float'>", None, 54, 54, 0, True), ('OtherPay', "<class 'float'>", None, 54, 54, 0, True), ('Benefits', "<class 'float'>", None, 54, 54, 0, True), ('TotalPay', "<class 'float'>", None, 54, 54, 0, True), ('TotalPayBenefits', "<class 'float'>", None, 54, 54, 0, True), ('Year', "<class 'int'>", None, 10, 10, 0, True), ('Notes', "<class 'str'>", None, 65536, 65536, 0, True), ('Agency', "<class 'str'>", None, 65536, 65536, 0, True), ('Status', "<class 'str'>", None, 65536, 65536, 0, True))

# precisamos 1º de uma lista com o nome das colunas para poder organizar as colunas da nossa tabela:
# o nome das colunas está na variável descrição, dê uma olhada.

import pandas as pd


# tabela = pd.DataFrame.from_records(informacoes)
# para acertar nossa tabela, vamos precisar fazer:
tabela = pd.DataFrame.from_records(informacoes, columns=colunas) # onde colunas é uma lista com o nome das colunas
display(tabela)


# além disso, precisamos enviar por e-mail para o RH uma lista com o nome e o cargo de cada pessoa da tabela
# então você precisa construir o texto do corpo desse email do tipo:

# texto = """
# RH, segue a lista dos funcionários:
# Fulano, Cargo: tal
# Beltrano, Cargo: isso
# """

# %% [markdown]
# ### 3 - Extração dos links de Download de Vídeos do Vimeo
#
# - Precisamos pegar os links em 1080p, 720p e 540p para importar os vídeos para uma nova plataforma

# %%
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo

import pprint

informacoes = dicionario_vimeo['data']
primeiro_item = informacoes[0]

# pprint.pprint(primeiro_item)

# video_uri = primeiro_item['uri']
# nome_video = primeiro_item['name']
# duracao = primeiro_item['duration']
# print(video_uri, nome_video, duracao)

# for item in informacoes:
#   video_uri = item['uri']
#   nome_video = item['name']
#   duracao = item['duration']
#   print(video_uri, nome_video, duracao)


# pprint.pprint(nome_video)
# pprint.pprint(dicionario_vimeo)

# # print(dicionario_vimeo)
# dados = dicionario_vimeo['data']
# # print(dados)
# for chave in dados:
#   print(chave)

# TODO
# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]

video_uri = primeiro_item['uri']
nome_video = primeiro_item['name']
duracao = primeiro_item['duration']
# print(video_uri, nome_video, duracao)

link540p = ""
link720p = ""
link1080p = ""
lista_downloads = primeiro_item['download']
for dicionario_download in lista_downloads:
  if dicionario_download['rendition'] == '540p':
    link540p = dicionario_download['link']
  if dicionario_download['rendition'] == '720p':
    link720p = dicionario_download['link']
  if dicionario_download['rendition'] == '1080p':
    link1080p = dicionario_download['link']

print('video_uri:', video_uri,'nome_video:', nome_video,'duracao:', duracao)
print('link540p',link540p)
print('link720p',link720p)
print('link1080p',link1080p)
# Out:
# video_uri: /videos/210375279 nome_video: Aula 2.3 duracao: 160
# link540p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064
# link720p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096
# link1080p

# %% [markdown]
# CODIGO SOMENTE PARA O PRIMEIRO ITEM

# %%
# TODO
# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo
import pprint

informacoes = dicionario_vimeo['data']
primeiro_item = informacoes[0]

pprint.pprint(primeiro_item)
video_uri = primeiro_item['uri']
nome_video = primeiro_item['name']
duracao = primeiro_item['duration']

link540p = ""
link720p = ""
link1080p = ""
lista_downloads = primeiro_item['download']
for dicionario_download in lista_downloads:
  if dicionario_download['rendition'] == '540p':
    link540p = dicionario_download['link']
  if dicionario_download['rendition'] == '720p':
    link720p = dicionario_download['link']
  if dicionario_download['rendition'] == '1080p':
    link1080p = dicionario_download['link']

print('video_uri:', video_uri,'nome_video:', nome_video,'duracao:', duracao)
print('link540p',link540p)
print('link720p',link720p)
print('link1080p',link1080p)
# Out:
# {'app': None,
#  'categories': [],
#  'content_rating': ['unrated'],
#  'content_rating_class': 'unrated',
#  'created_time': '2017-03-28T04:17:04+00:00',
#  'description': None,
#  'download': [{'created_time': '2017-03-28T04:30:48+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 720,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096',
#                'md5': 'd70993f6faf13cf8d8facaea20695c9e',
#                'public_name': '720p',
#                'quality': 'hd',
#                'rendition': '720p',
#                'size': 12618045,
#                'size_short': '12.03MB',
#                'type': 'video/mp4',
#                'width': 1280},
#               {'created_time': '2017-03-28T04:30:48+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 360,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/bb1d7264/aula_2.3%20%28360p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=461ee7f0d37bcabf8d9686271f3f9c3fe45e66bb410b8a20c9dea53a84e98d68',
#                'md5': '19939f6f0e2a23f2202661482ef8aae1',
#                'public_name': '360p',
#                'quality': 'sd',
#                'rendition': '360p',
#                'size': 5188016,
#                'size_short': '4.95MB',
#                'type': 'video/mp4',
#                'width': 640},
#               {'created_time': '2017-03-28T04:30:48+00:00',
#                'expires': '2022-08-19T14:51:49+00:00',
#                'fps': 24,
#                'height': 540,
#                'link': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064',
#                'md5': '049b32c918b24f68fc4abc0528e7072f',
#                'public_name': '540p',
#                'quality': 'sd',
#                'rendition': '540p',
#                'size': 9827506,
#                'size_short': '9.37MB',
#                'type': 'video/mp4',
#                'width': 960}],
#  'duration': 160,
#  'embed': {'badges': {'hdr': False,
#                       'live': {'archived': False, 'streaming': False},
#                       'staff_pick': {'best_of_the_month': False,
#                                      'best_of_the_year': False,
#                                      'normal': False,
#                                      'premiere': False},
#                       'vod': False,
#                       'weekend_challenge': False},
#            'buttons': {'embed': False,
#                        'fullscreen': False,
#                        'hd': False,
#                        'like': False,
#                        'scaling': True,
#                        'share': False,
#                        'watchlater': False},
#            'color': '00adef',
#            'end_screen': {'type': 'empty'},
#            'event_schedule': True,
#            'html': '<iframe '
#                    'src="https://player.vimeo.com/video/210375279?h=d8e5156450&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=252054" '
#                    'width="1364" height="768" frameborder="0" allow="autoplay; '
#                    'fullscreen; picture-in-picture" allowfullscreen '
#                    'title="Aula 2.3"></iframe>',
#            'interactive': False,
#            'logos': {'custom': {'active': False,
#                                 'link': None,
#                                 'sticky': False,
#                                 'url': None},
#                      'vimeo': False},
#            'playbar': True,
#            'speed': True,
#            'title': {'name': 'hide', 'owner': 'hide', 'portrait': 'hide'},
#            'uri': '/presets/120509281',
#            'volume': True},
#  'files': [{'created_time': '2017-03-28T04:30:48+00:00',
#             'fps': 24,
#             'height': 720,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/rendition/720p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=b1ce3195a4f14235e13892bcbe9cdcf965c7b68bcd07338110c690d1207136b1',
#             'md5': 'd70993f6faf13cf8d8facaea20695c9e',
#             'public_name': '720p',
#             'quality': 'hd',
#             'rendition': '720p',
#             'size': 12618045,
#             'size_short': '12.03MB',
#             'type': 'video/mp4',
#             'width': 1280},
#            {'created_time': '2017-03-28T04:30:48+00:00',
#             'fps': 24,
#             'height': 360,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/rendition/360p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=b1db4793607f196f6ebd3cec32533c3dbf3b95feb10a5b3cd1cbce08860a6d10',
#             'md5': '19939f6f0e2a23f2202661482ef8aae1',
#             'public_name': '360p',
#             'quality': 'sd',
#             'rendition': '360p',
#             'size': 5188016,
#             'size_short': '4.95MB',
#             'type': 'video/mp4',
#             'width': 640},
#            {'created_time': '2017-03-28T04:30:48+00:00',
#             'fps': 24,
#             'height': 540,
#             'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/rendition/540p/file.mp4?loc=external&oauth2_token_id=1656777045&signature=f1e563cd140df866f8966efcaf87acb314936464f5b071b3f169dd15dd955c04',
#             'md5': '049b32c918b24f68fc4abc0528e7072f',
#             'public_name': '540p',
#             'quality': 'sd',
#             'rendition': '540p',
#             'size': 9827506,
#             'size_short': '9.37MB',
#             'type': 'video/mp4',
#             'width': 960},
#            {'created_time': '2017-03-28T04:30:48+00:00',
#             'fps': 24,
#             'link': 'https://player.vimeo.com/external/210375279.m3u8?s=a435e2d06392f654ecb8a947ba494da7a2913561&oauth2_token_id=1656777045',
#             'md5': 'd70993f6faf13cf8d8facaea20695c9e',
#             'public_name': '720p',
#             'quality': 'hls',
#             'rendition': 'adaptive',
#             'size': 12618045,
#             'size_short': '12.03MB',
#             'type': 'video/mp4'}],
#  'has_audio': True,
#  'height': 768,
#  'is_playable': True,
#  'language': None,
#  'last_user_action_event_date': '2020-09-24T17:10:39+00:00',
#  'license': None,
#  'link': 'https://vimeo.com/210375279',
#  'manage_link': '/manage/videos/210375279',
#  'metadata': {'connections': {'albums': {'options': ['GET', 'PATCH'],
#                                          'total': 0,
#                                          'uri': '/videos/210375279/albums'},
#                               'available_albums': {'options': ['GET'],
#                                                    'total': 1,
#                                                    'uri': '/videos/210375279/available_albums'},
#                               'available_channels': {'options': ['GET'],
#                                                      'total': 0,
#                                                      'uri': '/videos/210375279/available_channels'},
#                               'comments': {'options': ['GET', 'POST'],
#                                            'total': 0,
#                                            'uri': '/videos/210375279/comments'},
#                               'credits': {'options': ['GET', 'POST'],
#                                           'total': 0,
#                                           'uri': '/videos/210375279/credits'},
#                               'likes': {'options': ['GET'],
#                                         'total': 3,
#                                         'uri': '/videos/210375279/likes'},
#                               'pictures': {'options': ['GET', 'POST'],
#                                            'total': 1,
#                                            'uri': '/videos/210375279/pictures'},
#                               'recommendations': {'options': ['GET'],
#                                                   'uri': '/videos/210375279/recommendations'},
#                               'related': {'options': ['GET'],
#                                           'uri': '/users/64746254/videos?per_page=100&page=46&offset=1'},
#                               'texttracks': {'options': ['GET', 'POST'],
#                                              'total': 0,
#                                              'uri': '/videos/210375279/texttracks'}},
#               'interactions': {'can_update_privacy_to_public': {'options': ['PATCH'],
#                                                                 'uri': '/videos/210375279'},
#                                'delete': {'options': ['DELETE'],
#                                           'uri': '/videos/210375279'},
#                                'edit': {'blocked_fields': [],
#                                         'options': ['PATCH'],
#                                         'uri': '/videos/210375279'},
#                                'edit_content_rating': {'content_rating': ['language',
#                                                                           'drugs',
#                                                                           'violence',
#                                                                           'nudity',
#                                                                           'advertisement',
#                                                                           'safe',
#                                                                           'unrated'],
#                                                        'options': ['PATCH'],
#                                                        'uri': '/videos/210375279'},
#                                'edit_privacy': {'content_type': 'application/vnd.vimeo.video',
#                                                 'options': ['PATCH'],
#                                                 'properties': [{'name': 'privacy.view',
#                                                                 'options': ['anybody',
#                                                                             'nobody',
#                                                                             'password',
#                                                                             'disable',
#                                                                             'unlisted'],
#                                                                 'required': True}],
#                                                 'uri': '/videos/210375279'},
#                                'report': {'options': ['POST'],
#                                           'reason': ['pornographic',
#                                                      'harassment',
#                                                      'ripoff',
#                                                      'incorrect rating',
#                                                      'spam',
#                                                      'causes harm',
#                                                      'csam'],
#                                           'uri': '/videos/210375279/report'},
#                                'trim': {'options': ['GET', 'POST'],
#                                         'uri': '/videos/210375279/cliptrim'},
#                                'validate': {'options': ['PUT'],
#                                             'uri': '/videos/210375279/validate'},
#                                'view_team_members': {'options': ['GET'],
#                                                      'uri': '/videos/210375279/teammembers'},
#                                'watchlater': {'added': False,
#                                               'added_time': None,
#                                               'options': ['GET',
#                                                           'PUT',
#                                                           'DELETE'],
#                                               'uri': '/users/64746254/watchlater/210375279'}},
#               'is_screen_record': False,
#               'is_vimeo_create': False},
#  'modified_time': '2022-08-17T21:18:23+00:00',
#  'name': 'Aula 2.3',
#  'parent_folder': None,
#  'pictures': {'active': True,
#               'base_link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d',
#               'default_picture': False,
#               'resource_key': '59050f2969b90b5b8297ca57011321af172b644c',
#               'sizes': [{'height': 75,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_100x75?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_100x75&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 100},
#                         {'height': 150,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_200x150?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_200x150&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 200},
#                         {'height': 166,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_295x166?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_295x166&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 295},
#                         {'height': 360,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_640x360?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_640x360&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 640},
#                         {'height': 540,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_960x540?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_960x540&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 960},
#                         {'height': 720,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_1280x720?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_1280x720&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 1280},
#                         {'height': 1080,
#                          'link': 'https://i.vimeocdn.com/video/626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_1920x1080?r=pad',
#                          'link_with_play_button': 'https://i.vimeocdn.com/filter/overlay?src0=https%3A%2F%2Fi.vimeocdn.com%2Fvideo%2F626145952-47e451651c2e0680b0fe4153083151ff08a965e9b2850d038f6606ce48c512c8-d_1920x1080&src1=http%3A%2F%2Ff.vimeocdn.com%2Fp%2Fimages%2Fcrawler_play.png',
#                          'width': 1920}],
#               'type': 'custom',
#               'uri': '/videos/210375279/pictures/626145952'},
#  'play': {'dash': {'link': 'https://player.vimeo.com/play/c/210375279/dash?s=210375279_1660920592_296920449a99b042697138799cb0c1df&context=Vimeo%5CController%5CApi%5CResources%5CUser%5CVideosController.&log_user=0&oauth2_token_id=1656777045',
#                    'link_expiration_time': '2022-08-19T14:49:52+00:00'},
#           'hls': {'link': 'https://player.vimeo.com/play/c/210375279/hls?s=210375279_1660920592_296920449a99b042697138799cb0c1df&context=Vimeo%5CController%5CApi%5CResources%5CUser%5CVideosController.&log_user=0&oauth2_token_id=1656777045',
#                   'link_expiration_time': '2022-08-19T14:49:52+00:00'},
#           'progressive': [{'codec': 'H264',
#                            'created_time': '2017-03-28T04:30:48+00:00',
#                            'fps': 24,
#                            'height': 720,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=6336703b07a7b8fd9664c49054ec3fae02effdc9169ce0c42c13cadf92235158',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': 'd70993f6faf13cf8d8facaea20695c9e',
#                            'size': 12618045,
#                            'type': 'video/mp4',
#                            'width': 1280},
#                           {'codec': 'H264',
#                            'created_time': '2017-03-28T04:30:48+00:00',
#                            'fps': 24,
#                            'height': 360,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/bb1d7264?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=00c7e9886ed2a94aa0793ea01f4a9523e1e4874dbdb742c89698b28bb9307c4b',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': '19939f6f0e2a23f2202661482ef8aae1',
#                            'size': 5188016,
#                            'type': 'video/mp4',
#                            'width': 640},
#                           {'codec': 'H264',
#                            'created_time': '2017-03-28T04:30:48+00:00',
#                            'fps': 24,
#                            'height': 540,
#                            'link': 'https://player.vimeo.com/progressive_redirect/playback/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6?expires=1660920709&loc=external&log_user=0&oauth2_token_id=1656777045&signature=9701069836dc520de5606907aabab32764cd9d87da05217c5dfd1122a5237c37',
#                            'link_expiration_time': '2022-08-19T14:51:49+00:00',
#                            'md5': '049b32c918b24f68fc4abc0528e7072f',
#                            'size': 9827506,
#                            'type': 'video/mp4',
#                            'width': 960}],
#           'status': 'playable'},
#  'player_embed_url': 'https://player.vimeo.com/video/210375279?h=d8e5156450',
#  'privacy': {'add': False,
#              'comments': 'anybody',
#              'download': False,
#              'embed': 'public',
#              'view': 'anybody'},
#  'rating_mod_locked': False,
#  'release_time': '2017-03-28T04:17:04+00:00',
#  'resource_key': '8ba6fdb17f18a575a6294059709291eea703e005',
#  'review_page': {'active': True,
#                  'link': 'https://vimeo.com/user64746254/review/210375279/0a7606f896'},
#  'stats': {'plays': 20005},
#  'status': 'available',
#  'tags': [],
#  'transcode': {'status': 'complete'},
#  'type': 'video',
#  'upload': {'approach': None,
#             'complete_uri': None,
#             'form': None,
#             'link': None,
#             'redirect_url': None,
#             'size': None,
#             'status': 'complete',
#             'upload_link': None},
#  'uploader': {'pictures': {'active': False,
#                            'base_link': 'https://i.vimeocdn.com/portrait/defaults-blue',
#                            'default_picture': True,
#                            'resource_key': '06cd312fcc3908e2d839aeb00ccaaf434acb0859',
#                            'sizes': [{'height': 30,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_30x30',
#                                       'width': 30},
#                                      {'height': 72,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_72x72',
#                                       'width': 72},
#                                      {'height': 75,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_75x75',
#                                       'width': 75},
#                                      {'height': 100,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_100x100',
#                                       'width': 100},
#                                      {'height': 144,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_144x144',
#                                       'width': 144},
#                                      {'height': 216,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_216x216',
#                                       'width': 216},
#                                      {'height': 288,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_288x288',
#                                       'width': 288},
#                                      {'height': 300,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_300x300',
#                                       'width': 300},
#                                      {'height': 360,
#                                       'link': 'https://i.vimeocdn.com/portrait/defaults-blue_360x360',
#                                       'width': 360}],
#                            'type': 'default',
#                            'uri': None}},
#  'uri': '/videos/210375279',
#  'user': {'account': 'pro',
#           'available_for_hire': False,
#           'bio': None,
#           'can_work_remotely': False,
#           'capabilities': {'hasEnterpriseLihp': False,
#                            'hasLiveSubscription': False,
#                            'hasSvvTimecodedComments': False},
#           'content_filter': ['language',
#                              'drugs',
#                              'violence',
#                              'nudity',
#                              'safe',
#                              'unrated'],
#           'created_time': '2017-03-27T22:17:43+00:00',
#           'gender': '',
#           'link': 'https://vimeo.com/user64746254',
#           'location': '',
#           'location_details': {'city': None,
#                                'country': None,
#                                'country_iso_code': None,
#                                'formatted_address': '',
#                                'latitude': None,
#                                'longitude': None,
#                                'neighborhood': None,
#                                'state': None,
#                                'state_iso_code': None,
#                                'sub_locality': None},
#           'metadata': {'connections': {'albums': {'options': ['GET'],
#                                                   'total': 1,
#                                                   'uri': '/users/64746254/albums'},
#                                        'appearances': {'options': ['GET'],
#                                                        'total': 0,
#                                                        'uri': '/users/64746254/appearances'},
#                                        'block': {'options': ['GET'],
#                                                  'total': 0,
#                                                  'uri': '/me/block'},
#                                        'categories': {'options': ['GET'],
#                                                       'total': 0,
#                                                       'uri': '/users/64746254/categories'},
#                                        'channels': {'options': ['GET'],
#                                                     'total': 0,
#                                                     'uri': '/users/64746254/channels'},
#                                        'feed': {'options': ['GET'],
#                                                 'uri': '/users/64746254/feed'},
#                                        'folders': {'options': ['GET', 'POST'],
#                                                    'total': 1,
#                                                    'uri': '/users/64746254/folders'},
#                                        'folders_root': {'options': ['GET'],
#                                                         'uri': '/users/64746254/folders/root'},
#                                        'followers': {'options': ['GET'],
#                                                      'total': 176,
#                                                      'uri': '/users/64746254/followers'},
#                                        'following': {'options': ['GET'],
#                                                      'total': 0,
#                                                      'uri': '/users/64746254/following'},
#                                        'groups': {'options': ['GET'],
#                                                   'total': 0,
#                                                   'uri': '/users/64746254/groups'},
#                                        'likes': {'options': ['GET'],
#                                                  'total': 0,
#                                                  'uri': '/users/64746254/likes'},
#                                        'membership': {'options': ['PATCH'],
#                                                       'uri': '/users/64746254/membership/'},
#                                        'moderated_channels': {'options': ['GET'],
#                                                               'total': 0,
#                                                               'uri': '/users/64746254/channels?filter=moderated'},
#                                        'permission_policies': {'options': ['GET'],
#                                                                'total': 8,
#                                                                'uri': '/users/64746254/permission_policies'},
#                                        'pictures': {'options': ['GET', 'POST'],
#                                                     'total': 0,
#                                                     'uri': '/users/64746254/pictures'},
#                                        'portfolios': {'options': ['GET'],
#                                                       'total': 0,
#                                                       'uri': '/users/64746254/portfolios'},
#                                        'shared': {'options': ['GET'],
#                                                   'total': 0,
#                                                   'uri': '/users/64746254/shared/videos'},
#                                        'teams': {'options': ['GET'],
#                                                  'total': 1,
#                                                  'uri': '/users/64746254/teams'},
#                                        'videos': {'options': ['GET'],
#                                                   'total': 4510,
#                                                   'uri': '/users/64746254/videos'},
#                                        'watched_videos': {'options': ['GET'],
#                                                           'total': 0,
#                                                           'uri': '/me/watched/videos'},
#                                        'watchlater': {'options': ['GET'],
#                                                       'total': 1,
#                                                       'uri': '/users/64746254/watchlater'}}},
#           'name': 'Hashtag Treinamentos',
#           'pictures': {'active': False,
#                        'base_link': 'https://i.vimeocdn.com/portrait/defaults-blue',
#                        'default_picture': True,
#                        'resource_key': '06cd312fcc3908e2d839aeb00ccaaf434acb0859',
#                        'sizes': [{'height': 30,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_30x30',
#                                   'width': 30},
#                                  {'height': 72,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_72x72',
#                                   'width': 72},
#                                  {'height': 75,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_75x75',
#                                   'width': 75},
#                                  {'height': 100,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_100x100',
#                                   'width': 100},
#                                  {'height': 144,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_144x144',
#                                   'width': 144},
#                                  {'height': 216,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_216x216',
#                                   'width': 216},
#                                  {'height': 288,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_288x288',
#                                   'width': 288},
#                                  {'height': 300,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_300x300',
#                                   'width': 300},
#                                  {'height': 360,
#                                   'link': 'https://i.vimeocdn.com/portrait/defaults-blue_360x360',
#                                   'width': 360}],
#                        'type': 'default',
#                        'uri': None},
#           'preferences': {'videos': {'privacy': {'add': True,
#                                                  'comments': 'anybody',
#                                                  'download': True,
#                                                  'embed': 'public',
#                                                  'view': 'disable'},
#                                      'rating': ['unrated']}},
#           'resource_key': 'd9abdf36f4f1e328e1d085932436ac8647a3346d',
#           'short_bio': None,
#           'skills': [],
#           'upload_quota': {'lifetime': {'free': None,
#                                         'max': None,
#                                         'unit': None,
#                                         'used': None},
#                            'periodic': {'free': 21222207576,
#                                         'max': 21474836480,
#                                         'period': 'week',
#                                         'reset_date': '2022-08-23T00:00:00-04:00',
#                                         'unit': 'video_size',
#                                         'used': 252628904},
#                            'space': {'free': 21222207576,
#                                      'max': 21474836480,
#                                      'showing': 'periodic',
#                                      'unit': 'video_size',
#                                      'used': 252628904}},
#           'uri': '/users/64746254',
#           'websites': []},
#  'width': 1364}
# video_uri: /videos/210375279 nome_video: Aula 2.3 duracao: 160
# link540p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064
# link720p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096
# link1080p

# %% [markdown]
# CODIGO PARA PEGAR TODOS, APÓS CRIAR A LOGICA DE PEGAR O PRIMEIRO, ADAPTE PARA PEGAR TODOS, ALTERANDO APENAS O ITEM SELECIONADO NO CODIGO

# %%
# TODO
# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo
import pprint

informacoes = dicionario_vimeo['data']

for item in informacoes:
  video_uri = item['uri']
  nome_video = item['name']
  duracao = item['duration']

  link540p = ""
  link720p = ""
  link1080p = ""
  lista_downloads = item['download']
  for dicionario_download in lista_downloads:
    if dicionario_download['rendition'] == '540p':
      link540p = dicionario_download['link']
    if dicionario_download['rendition'] == '720p':
      link720p = dicionario_download['link']
    if dicionario_download['rendition'] == '1080p':
      link1080p = dicionario_download['link']

  print('video_uri:', video_uri,'nome_video:', nome_video,'duracao:', duracao)
  print('link540p',link540p)
  print('link720p',link720p)
  print('link1080p',link1080p)
# Out:
# video_uri: /videos/210375279 nome_video: Aula 2.3 duracao: 160
# link540p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064
# link720p https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096
# link1080p
# video_uri: /videos/210374410 nome_video: Aula 2.2 duracao: 122
# link540p https://player.vimeo.com/progressive_redirect/download/210374410/container/d03031bd-2244-4ade-b0ab-2100d0d32536/99846e57/aula_2.2%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=2826255c282b7897ad64c3f120f1c9d9e1dcd4ae664a3e24f8489a647990bcc4
# link720p https://player.vimeo.com/progressive_redirect/download/210374410/container/d03031bd-2244-4ade-b0ab-2100d0d32536/4885397e/aula_2.2%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f859adf52cbc89c7871dd07db84b33e42181bdbf0eeef9414ffa1b3f8dc8ec9b
# link1080p
# video_uri: /videos/210373284 nome_video: Aula 2.1 duracao: 186
# link540p https://player.vimeo.com/progressive_redirect/download/210373284/container/0291605f-62f8-4d09-9fb9-5b24f9f1e07c/114ab8b1/aula_2.1%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=c268a41698cf53ad34a0110b951eabfed91c62116c13784b30fafd254cd81077
# link720p https://player.vimeo.com/progressive_redirect/download/210373284/container/0291605f-62f8-4d09-9fb9-5b24f9f1e07c/95a2e7df/aula_2.1%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=b817d1fcf5b39fb52f0ae8ef272cd6749c2692fd742cb752b6e8626d5c8a880b
# link1080p
# video_uri: /videos/210365639 nome_video: Aula 3.4 duracao: 200
# link540p https://player.vimeo.com/progressive_redirect/download/210365639/container/2bf500d1-73b5-4e87-98f5-292b4f736f41/d0ec08f4/aula_3.4%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f0cb8457462bc1a007cbee9cd393da8883c816fad73fe91700d6806519419e7b
# link720p https://player.vimeo.com/progressive_redirect/download/210365639/container/2bf500d1-73b5-4e87-98f5-292b4f736f41/7fb3a467/aula_3.4%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=1196773401c288be1b0e01b81dd083c811c8bc0a12fa5bc8f88d29dd869b2bba
# link1080p
# video_uri: /videos/210364466 nome_video: Aula 1.6 duracao: 147
# link540p https://player.vimeo.com/progressive_redirect/download/210364466/container/cabafb2a-17a9-4906-acb4-abe71289b16e/c87860ab/aula_1.6%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=a0a091216b1ef20aff73c133a0ca5985c22bbf7f1ca5263efc19ad8d063904a1
# link720p https://player.vimeo.com/progressive_redirect/download/210364466/container/cabafb2a-17a9-4906-acb4-abe71289b16e/0ba33f7d/aula_1.6%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=fc4dbcd54f2bcd2c273f2cd927917cba4747fcc64124db14a03343b40ad04508
# link1080p
# video_uri: /videos/210349630 nome_video: Aula 1.5 duracao: 103
# link540p https://player.vimeo.com/progressive_redirect/download/210349630/container/9a46e2c8-196c-41e9-830d-d03d87ef7999/a25735d9/aula_1.5%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=a120787c32cb1c52244ad30aafdddb4e37fcd1ff7b0884f7ba649969dbe0c7a5
# link720p https://player.vimeo.com/progressive_redirect/download/210349630/container/9a46e2c8-196c-41e9-830d-d03d87ef7999/1e9688c6/aula_1.5%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=e40a15ab8236e5098319c564e370b1c73c4c50a3a1b78429013be46d49fb04f2
# link1080p
# video_uri: /videos/210348003 nome_video: Aula 1.4 duracao: 163
# link540p https://player.vimeo.com/progressive_redirect/download/210348003/container/4296ecfc-9d2d-4ffe-aab7-28079e21a0c0/15c3fd1a/aula_1.4%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f69c7bf0733bdd74a5ea92c13654fda35d7210bb64af5031fe65d65da24d2e73
# link720p https://player.vimeo.com/progressive_redirect/download/210348003/container/4296ecfc-9d2d-4ffe-aab7-28079e21a0c0/b3002469/aula_1.4%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=afe3e20c89e08f8b1d87f260ec88705c15f3a787b448c2ec742d0678aa280662
# link1080p
# video_uri: /videos/210346986 nome_video: Aula 1.3 duracao: 88
# link540p https://player.vimeo.com/progressive_redirect/download/210346986/container/070b094e-8185-46ef-a6d4-521535deab9b/9376b5a3/aula_1.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=05c17abe970063a548407795b2711e5ab59148729f8ff907e609c8fa3a19d36b
# link720p https://player.vimeo.com/progressive_redirect/download/210346986/container/070b094e-8185-46ef-a6d4-521535deab9b/8a39fa7b/aula_1.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=5c906be012759781b2ad5373355681fa7b8d8fdcb758cb000241b553b0ca6fc1
# link1080p
# video_uri: /videos/210345205 nome_video: Aula 1.2 duracao: 165
# link540p https://player.vimeo.com/progressive_redirect/download/210345205/container/10d834ed-4b52-4986-bc05-2f585ede2b4d/7748a8fa/aula_1.2%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f78faa3bcbecc8430e99631c79b49f57c34f03485e4d2c0b3d402ead6087b91a
# link720p https://player.vimeo.com/progressive_redirect/download/210345205/container/10d834ed-4b52-4986-bc05-2f585ede2b4d/b58e1e25/aula_1.2%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=8dbd2336fba8a05e05070b5b7207936a56326c193233b91e1c6f7e31ab294c7a
# link1080p
# video_uri: /videos/210341989 nome_video: Aula 1.1 duracao: 133
# link540p https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/7f4a2f6c/aula_1.1%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=c5febad8768e842fa0e49fe92281d4321fc24ccd4dc8ca07131380821f6d07f2
# link720p https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/4a773fd4/aula_1.1%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=caad8ac609cd654af234aba6004f5299f2b432e4d97a5b5d0f8999b009d0d0cb
# link1080p

# %% [markdown]
# ULTIMA ETAPA, AO INVES DE PRINTAR SOMENTE A INFORMACAO, A GENTE VAI ADICIONAR NUMA LISTA(DICIONARIO PYTHON)

# %%
# TODO
# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]
# para pegar o dicionario do vimeo, use:
from dic import dicionario_vimeo
import pprint

informacoes = dicionario_vimeo['data']
videos = []
for item in informacoes:
  video_uri = item['uri']
  nome_video = item['name']
  duracao = item['duration']

  link540p = ""
  link720p = ""
  link1080p = ""
  lista_downloads = item['download']
  for dicionario_download in lista_downloads:
    if dicionario_download['rendition'] == '540p':
      link540p = dicionario_download['link']
    if dicionario_download['rendition'] == '720p':
      link720p = dicionario_download['link']
    if dicionario_download['rendition'] == '1080p':
      link1080p = dicionario_download['link']

  dic_item = {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p}
  videos.append(dic_item)
pprint.pprint(videos)
  # print('video_uri:', video_uri,'nome_video:', nome_video,'duracao:', duracao)
  # print('link540p',link540p)
  # print('link720p',link720p)
  # print('link1080p',link1080p)
# Out:
# [{'duracao': 160,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/c103cec6/aula_2.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=359dd9db8ea5946c85acb4bf7b676012b00ded2abef9ee20d4af1be8141fa064',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210375279/container/dfe0033c-59dc-4504-8f72-9a9137200e09/8c89659d/aula_2.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=622e5e832382c2a1cb4b0902b3dda63ebc41b53668d65267840bd3aa2b10e096',
#   'nome': 'Aula 2.3',
#   'uri': '/videos/210375279'},
#  {'duracao': 122,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210374410/container/d03031bd-2244-4ade-b0ab-2100d0d32536/99846e57/aula_2.2%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=2826255c282b7897ad64c3f120f1c9d9e1dcd4ae664a3e24f8489a647990bcc4',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210374410/container/d03031bd-2244-4ade-b0ab-2100d0d32536/4885397e/aula_2.2%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f859adf52cbc89c7871dd07db84b33e42181bdbf0eeef9414ffa1b3f8dc8ec9b',
#   'nome': 'Aula 2.2',
#   'uri': '/videos/210374410'},
#  {'duracao': 186,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210373284/container/0291605f-62f8-4d09-9fb9-5b24f9f1e07c/114ab8b1/aula_2.1%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=c268a41698cf53ad34a0110b951eabfed91c62116c13784b30fafd254cd81077',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210373284/container/0291605f-62f8-4d09-9fb9-5b24f9f1e07c/95a2e7df/aula_2.1%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=b817d1fcf5b39fb52f0ae8ef272cd6749c2692fd742cb752b6e8626d5c8a880b',
#   'nome': 'Aula 2.1',
#   'uri': '/videos/210373284'},
#  {'duracao': 200,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210365639/container/2bf500d1-73b5-4e87-98f5-292b4f736f41/d0ec08f4/aula_3.4%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f0cb8457462bc1a007cbee9cd393da8883c816fad73fe91700d6806519419e7b',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210365639/container/2bf500d1-73b5-4e87-98f5-292b4f736f41/7fb3a467/aula_3.4%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=1196773401c288be1b0e01b81dd083c811c8bc0a12fa5bc8f88d29dd869b2bba',
#   'nome': 'Aula 3.4',
#   'uri': '/videos/210365639'},
#  {'duracao': 147,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210364466/container/cabafb2a-17a9-4906-acb4-abe71289b16e/c87860ab/aula_1.6%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=a0a091216b1ef20aff73c133a0ca5985c22bbf7f1ca5263efc19ad8d063904a1',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210364466/container/cabafb2a-17a9-4906-acb4-abe71289b16e/0ba33f7d/aula_1.6%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=fc4dbcd54f2bcd2c273f2cd927917cba4747fcc64124db14a03343b40ad04508',
#   'nome': 'Aula 1.6',
#   'uri': '/videos/210364466'},
#  {'duracao': 103,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210349630/container/9a46e2c8-196c-41e9-830d-d03d87ef7999/a25735d9/aula_1.5%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=a120787c32cb1c52244ad30aafdddb4e37fcd1ff7b0884f7ba649969dbe0c7a5',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210349630/container/9a46e2c8-196c-41e9-830d-d03d87ef7999/1e9688c6/aula_1.5%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=e40a15ab8236e5098319c564e370b1c73c4c50a3a1b78429013be46d49fb04f2',
#   'nome': 'Aula 1.5',
#   'uri': '/videos/210349630'},
#  {'duracao': 163,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210348003/container/4296ecfc-9d2d-4ffe-aab7-28079e21a0c0/15c3fd1a/aula_1.4%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f69c7bf0733bdd74a5ea92c13654fda35d7210bb64af5031fe65d65da24d2e73',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210348003/container/4296ecfc-9d2d-4ffe-aab7-28079e21a0c0/b3002469/aula_1.4%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=afe3e20c89e08f8b1d87f260ec88705c15f3a787b448c2ec742d0678aa280662',
#   'nome': 'Aula 1.4',
#   'uri': '/videos/210348003'},
#  {'duracao': 88,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210346986/container/070b094e-8185-46ef-a6d4-521535deab9b/9376b5a3/aula_1.3%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=05c17abe970063a548407795b2711e5ab59148729f8ff907e609c8fa3a19d36b',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210346986/container/070b094e-8185-46ef-a6d4-521535deab9b/8a39fa7b/aula_1.3%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=5c906be012759781b2ad5373355681fa7b8d8fdcb758cb000241b553b0ca6fc1',
#   'nome': 'Aula 1.3',
#   'uri': '/videos/210346986'},
#  {'duracao': 165,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210345205/container/10d834ed-4b52-4986-bc05-2f585ede2b4d/7748a8fa/aula_1.2%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=f78faa3bcbecc8430e99631c79b49f57c34f03485e4d2c0b3d402ead6087b91a',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210345205/container/10d834ed-4b52-4986-bc05-2f585ede2b4d/b58e1e25/aula_1.2%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=8dbd2336fba8a05e05070b5b7207936a56326c193233b91e1c6f7e31ab294c7a',
#   'nome': 'Aula 1.2',
#   'uri': '/videos/210345205'},
#  {'duracao': 133,
#   'link1080p': '',
#   'link540p': 'https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/7f4a2f6c/aula_1.1%20%28540p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=c5febad8768e842fa0e49fe92281d4321fc24ccd4dc8ca07131380821f6d07f2',
#   'link720p': 'https://player.vimeo.com/progressive_redirect/download/210341989/container/70fdfaeb-46ee-4178-8ed7-569306b5ea91/4a773fd4/aula_1.1%20%28720p%29.mp4?expires=1660920709&loc=external&oauth2_token_id=1656777045&signature=caad8ac609cd654af234aba6004f5299f2b432e4d97a5b5d0f8999b009d0d0cb',
#   'nome': 'Aula 1.1',
#   'uri': '/videos/210341989'}]

# %% [markdown]
# # Nova seção
